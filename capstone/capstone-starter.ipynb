# %% [markdown]
# # Capstone Starter Notebook
#
# Outline:
# - Title + Abstract placeholder
# - Data: links and release notes (don’t paste private exports)
# - Methodology: planned features and validation design
# - Results placeholder
#
# Fill sections as work progresses.

# %% [markdown]
# # 00-setup
#
# This notebook contains setup instructions for the FlyRank capstone scaffold.
# - Install dependencies (duckdb, pandas, scikit-learn, jupyter)
# - Authenticate to Hugging Face to access the dataset (use read token)
# - Notebook conventions and file layout
